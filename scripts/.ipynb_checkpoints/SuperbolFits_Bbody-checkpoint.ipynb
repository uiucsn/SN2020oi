# %% [markdown]
# Alex Gagliano, 05/10/2020

# %% [markdown]
# Let's start by importing our required packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from astropy.time import Time
from collections import Counter
import glob
import os 

sns.set_context("talk")
sns.set_style("white")
sns.set_palette("Dark2")

# %%
5*np.log10(((1.71)*1.e7)/10) #
# Out:
# 31.16498055196077

# %%
np.abs(31.16498055196077 - 31.38230902086622)
# Out:
# 0.21732846890544977

# %%
np.abs(31.16498055196077 - 30.92345715408799)
# Out:
# 0.2415233978727791

# %%
#SDSS filters and AB mags:
#These effective wavelengths for SDSS filters are from Fukugita et al. (1996, AJ, 111, 1748) and are
#the wavelength weighted averages (effective wavelengths in their Table 2a, first row)

#Effective wavelengths (in Angs)
wle = {'u': 3560,  'g': 4830, 'r': 6260, 'i': 7670, 'z': 8890, 'y': 9600, 'Y': 9600,
       'U': 3600,  'B': 4380, 'V': 5450, 'R': 6410, 'G': 6730, 'I': 7980, 'J': 12200, 'H': 16300,
       'K': 21900, 'UVW2': 2030, 'UVM2': 2231, 'UVW1': 2634, 'F': 1516, 'N': 2267, 'o': 6790, 'c': 5330}
extco = {'u': 4.786,  'g': 3.587, 'r': 2.471, 'i': 1.798,  'z': 1.403, 'y': 1.228, 'Y': 1.228,
         'U': 4.744,  'B': 4.016, 'V': 3.011, 'R': 2.386, 'G': 2.216, 'I': 1.684, 'J': 0.813, 'H': 0.516,
         'K': 0.337, 'UVW2': 8.795, 'UVM2': 9.270, 'UVW1': 6.432,  'F': 8.054,  'N': 8.969, 'o': 2.185, 'c': 3.111}
#All values in 1e-11 erg/s/cm2/Angs
zp = {'u': 859.5, 'g': 466.9, 'r': 278.0, 'i': 185.2, 'z': 137.8, 'y': 118.2, 'Y': 118.2,
      'U': 417.5, 'B': 632.0, 'V': 363.1, 'R': 217.7, 'G': 240.0, 'I': 112.6, 'J': 31.47, 'H': 11.38,
      'K': 3.961, 'UVW2': 536.2, 'UVM2': 463.7, 'UVW1': 412.3, 'F': 4801., 'N': 2119., 'o': 236.2, 'c': 383.3}
# For Swift UVOT: S=UVW2, D=UVM2, A=UVW1

# %%
BBody_temps = pd.read_csv("/Users/alexgagliano/Documents/Research/2020oi/scripts/superbol/SBO_input/superbol_output_2020oi/BB_params_2020oi_AUBgVriz.txt", delimiter='\t')

# %%
os.chdir("/Users/alexgagliano/Documents/Research/2020oi/scripts/superbol/SBO_input/SBO_BBodyCurves")

# %%
files = glob.glob('/Users/alexgagliano/Documents/Research/2020oi/scripts/superbol/SBO_input/SBO_BBodyCurves/*.csv')
allFiles = []
for file in np.array(files):
    allFiles.append(file.split("/")[-1])

# %%
allFiles = np.unique([int(file.split("_")[0]) for file in allFiles])

# %%
model_data
# Out:
#         wave     BBody_Fit            ph
# 0        100  6.585050e-80  58856.886573
# 1        101  4.840798e-79  58856.886573
# 2        102  3.420730e-78  58856.886573
# 3        103  2.326301e-77  58856.886573
# 4        104  1.524194e-76  58856.886573
# ...      ...           ...           ...
# 24895  24995  2.341373e+00  58856.886573
# 24896  24996  2.341135e+00  58856.886573
# 24897  24997  2.340898e+00  58856.886573
# 24898  24998  2.340661e+00  58856.886573
# 24899  24999  2.340424e+00  58856.886573
#
# [24900 rows x 3 columns]

# %%
SN2020oi = pd.read_csv("/Users/alexgagliano/Documents/Research/2020oi/data/photometry/2020oiphotometry_clean_wUVOT.csv")
SN2020oi = SN2020oi[SN2020oi['FLT'] != 'orange']
SN2020oi.loc[SN2020oi['FLT'] == 'up', 'FLT'] = 'u'
SN2020oi.loc[SN2020oi['FLT'] == 'gp', 'FLT'] = 'g'
SN2020oi.loc[SN2020oi['FLT'] == 'g-ZTF', 'FLT'] = 'g'
SN2020oi.loc[SN2020oi['FLT'] == 'rp', 'FLT'] = 'r'
SN2020oi.loc[SN2020oi['FLT'] == 'r-ZTF', 'FLT'] = 'r'
SN2020oi.loc[SN2020oi['FLT'] == 'ip', 'FLT'] = 'i'

#Spectral radiance in units of erg/s/Angstrom
#1 Jy = 1.e-23 erg/s/cm^2/Hz
#Fnu = Flambda x (lambda**2) / c
sns.set_context("poster")

for date in allFiles:
    c = 2.998e10 #cm/s
    dm = 31.16
    dist = 1e-5*3.086e24
    
    real_data = pd.read_csv("%i_Data.csv"%date)
    model_data = pd.read_csv("%i_Model.csv"%date)

    #plt.plot(real_data['wave'],real_data['FluxData'], 'o')
    model_phase = model_data['ph'].values[0]
    print(model_phase)
    SN2020oi_cut = SN2020oi[np.abs(SN2020oi['MJD'] - model_phase) < 0.2]
    SN2020oi_cut['wle'] = np.array([wle[x] for x in SN2020oi_cut['FLT']])
    SN2020oi_cut['ext_corr'] = np.array([extco[x] for x in SN2020oi_cut['FLT']])
    
    # extinction-correction
    ebv = 0.174+0.028
    ebv2 = 0.174-0.028
    #ebv2 = 0.153 #horesh's value
    # Subtract foreground extinction using input E(B-V) and coefficients from YES
    SN2020oi_cut['MAG'] -= SN2020oi_cut['ext_corr']*ebv
    print(SN2020oi_cut['FLT'].values)
    print(SN2020oi_cut['ext_corr'].values*ebv - SN2020oi_cut['ext_corr'].values*ebv2)
    
    SN2020oi_cut['AbsMag'] = SN2020oi_cut['MAG']-dm
    
    #calculate zeropoints
    fref = np.array([zp[x]*1e-11 for x in SN2020oi_cut['FLT']])    
    SN2020oi_cut['flux'] = 4*np.pi*dist**2*fref*10**(-0.4*SN2020oi_cut['AbsMag'])
    #this gives flux in erg/s/Angstrom
    #first, get rid of the distance to get to erg/s/cm^2/Angstrom
    SN2020oi_cut['flux'] /= 4*np.pi*dist**2
    
    #next, use Fnu = Flambda x (lambda**2) / c
    SN2020oi_cut['flux'] *= SN2020oi_cut['wle']
#    SN2020oi_cut['flux'] *= SN2020oi_cut['wle']**2/c
#    SN2020oi_cut['flux'] /= 1.e-23
#    #convert Fnu to nu Fnu
    
    
    # convert mag errors to flux errors
    #ferr = 2.5/np.log(10) * flux * errs
    
    #First, get rid of the distance to get to erg/s/cm^2/Angstrom 
    model_data['BBody_Fit'] /= 4*np.pi*dist**2
    #next, use Fnu = Flambda x (lambda**2) / c
    model_data['BBody_Fit'] *= model_data['wave']
 #   model_data['BBody_Fit'] *= model_data['wave']**2/c
 #   #next, convert to Janskies
 #   model_data['BBody_Fit'] /= 1.e-23
    
    #convert Fnu to nu Fnu
    

    Tbb = BBody_temps.loc[np.abs(BBody_temps['ph'] - model_phase) < 0.01, 'T_bb'].values[0]
    Rbb = BBody_temps.loc[np.abs(BBody_temps['ph'] - model_phase) < 0.01, 'R_bb'].values[0]
    
    uvot_done = 0
    if (len(SN2020oi_cut) > 1) and (uvot_done == 0):
        plt.figure(figsize=(10,7))
        plt.plot(model_data['wave'], model_data['BBody_Fit'],lw=4)
        plt.plot(SN2020oi_cut['wle'], SN2020oi_cut['flux'], 'o')
        for uv in np.array(['UVM1', 'UVW1', 'UVW2']):
            if uv in SN2020oi_cut['FLT']:
                uvot_pt = SN2020oi_cut[SN2020oi_cut['FLT'].isin(['UVM1', 'UVW1', 'UVW2'])]
                plt.plot(uvot_pt['wle'], uvot_pt['flux'], '*', ms=10)
                uvot_done = 1
        plt.xscale("log")
        plt.yscale("log")
        #plt.xlim((500, 10000))
        #plt.ylim((1.e1, 1.e20))
        plt.xlabel("Wavelength (AA)")
        plt.ylabel(r"$\nu F_\nu$ (erg/s/cm$^2$)")
        plt.ylim(ymin=1.e-5)
        
        plt.tick_params(which='major', axis='x', direction='in', bottom=True, top=True, length=16, width=2)
        plt.tick_params(which='major', axis='y', direction='in', left=True, right=True, length=16, width=2)
        plt.tick_params(which='minor', axis='x', direction='in', bottom=True, top=True, length=8, width=2)
        plt.minorticks_on()
        plt.tick_params(which='minor', axis='y', direction='in', left=True, right=True, length=8, width=2)
        plt.text(1.e2, 2.e4, "$t$ (MJD) = %.2f"%model_phase)
        plt.text(1.e2, 5.e2, r"$T_{BB}$ = %.2f K"%Tbb)
        plt.text(1.e2, 1.e1, r"$R_{BB}$ = %.2f x $10^{14}$ cm"%float(Rbb/1.e14)) 
#        plt.savefig("2020oi_BBodyFit_MJD%2f.png"%date,dpi=300, bbox_inches='tight')
      #  break
# Out:
# 58856.88657314629
# ['UVW1' 'U' 'B' 'V' 'r' 'i' 'g' 'g' 'r' 'r' 'i' 'i']
# [0.360192 0.265664 0.224896 0.168616 0.138376 0.100688 0.200872 0.200872
#  0.138376 0.138376 0.100688 0.100688]
# 58857.8997995992
# ['g' 'g' 'r' 'r' 'i' 'i']
# [0.200872 0.200872 0.138376 0.138376 0.100688 0.100688]
# 58858.913026052105
# ['UVW1' 'U' 'B' 'V' 'g' 'r' 'i']
# [0.360192 0.265664 0.224896 0.168616 0.200872 0.138376 0.100688]
# /Users/alexgagliano/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/alexgagliano/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
