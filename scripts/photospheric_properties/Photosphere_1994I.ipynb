# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
SN1994I_phot = pd.read_csv("/Users/alexgagliano/Documents/Research/2020oi/data/SN1994I_Photosphere.csv")

# %%
sns.set_context("paper")
sns.set(font_scale=2, style='white')  # crazy big
plt.plot(SN1994I_phot['t(days)'], SN1994I_phot['T(K)'],'o')
plt.xlim((-8, 75))
plt.ylim((4.e3, 2.e4))
plt.yscale("log")
