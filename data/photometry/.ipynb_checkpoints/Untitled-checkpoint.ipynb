# %%
import pandas as pd
import matplotlib.pyplot as plt
LC = pd.read_csv("./GPC1v3_2020oi.snana.dat", delim_whitespace=True)

# %%
import seaborn as sns
sns.scatterplot(LC['MJD'], LC['MAG'], hue=LC['FLT'])
plt.gca().invert_yaxis()
